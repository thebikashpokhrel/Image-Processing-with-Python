# %% [markdown]
# ### Image Processing with Scipy and Skimage

# %%
from skimage import io
from scipy import ndimage
import numpy as np
from matplotlib import pyplot as plt

# %%
img = io.imread("../images/image-2.jpg",as_gray=True)
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
print(img.shape)
# Out:
# (427, 640, 3)

# %% [markdown]
# Flipping the images

# %%
flippedLR = np.fliplr(img)
flippedUD = np.flipud(img)

# %%
plt.subplot(2,1,1)
plt.imshow(img, cmap="Greys")

plt.subplot(2,2,3)
plt.imshow(flippedLR, cmap="Blues")

plt.subplot(2,2,4)
plt.imshow(flippedUD, cmap="hsv")

# %%
gaussian_filtered = ndimage.gaussian_filter(img,sigma=7)
plt.imshow(gaussian_filtered)
